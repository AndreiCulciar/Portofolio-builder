# %%
# !jupyter nbconvert --to script Untitled1.ipynb
# !jupyter nbconvert --to script Untitled2.ipynb
# !jupyter nbconvert --to script Untitled3.ipynb
# !jupyter nbconvert --to script Untitled4.ipynb
# Out:
# [NbConvertApp] Converting notebook Untitled1.ipynb to script
# [NbConvertApp] Writing 1344 bytes to Untitled1.py
# [NbConvertApp] Converting notebook Untitled2.ipynb to script
# [NbConvertApp] Writing 1905 bytes to Untitled2.py
# [NbConvertApp] Converting notebook Untitled3.ipynb to script
# [NbConvertApp] Writing 3138 bytes to Untitled3.py
# [NbConvertApp] Converting notebook Untitled4.ipynb to script
# [NbConvertApp] Writing 4542 bytes to Untitled4.py

# %%
# !python Untitled4.py
# Out:
# Running C:/Users/andre/Proiect stocuri/Untitled1.ipynb
#
# Executed C:/Users/andre/Proiect stocuri/Untitled1.ipynb
#
# Generated URL: https://finance.yahoo.com/markets/stocks/most-active/?start=0&count=5
#
# Stored 'df' (DataFrame)
#
# Running C:/Users/andre/Proiect stocuri/Untitled2.ipynb
#
# Executed C:/Users/andre/Proiect stocuri/Untitled2.ipynb
#
# Running C:/Users/andre/Proiect stocuri/Untitled3.ipynb
#
# Executed C:/Users/andre/Proiect stocuri/Untitled3.ipynb
#
# Stored 'q' (ndarray)
# Stored 'a' (list)
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# ...

# %%
# !pip install pyinstaller

# %%
# !pyinstaller Untitled4.py --onefile --windowed
# Out:
# 7980 INFO: PyInstaller: 6.13.0, contrib hooks: 2025.4
# 7981 INFO: Python: 3.11.7 (conda)
# 7990 INFO: Platform: Windows-10-10.0.19045-SP0
# 7990 INFO: Python environment: D:\Serpi
# 7990 INFO: wrote C:\Users\andre\Proiect stocuri\Untitled4.spec
# 8000 INFO: Module search paths (PYTHONPATH):
# ['D:\\Serpi\\Scripts\\pyinstaller.exe',
#  'D:\\Serpi\\python311.zip',
#  'D:\\Serpi\\DLLs',
#  'D:\\Serpi\\Lib',
#  'D:\\Serpi',
#  'D:\\Serpi\\Lib\\site-packages',
#  'D:\\Serpi\\Lib\\site-packages\\win32',
#  'D:\\Serpi\\Lib\\site-packages\\win32\\lib',
#  'D:\\Serpi\\Lib\\site-packages\\Pythonwin',
#  'C:\\Users\\andre\\Proiect stocuri']
# 10796 INFO: checking Analysis
# 11326 INFO: Building because C:\Users\andre\Proiect stocuri\Untitled4.py changed
# 11326 INFO: Running Analysis Analysis-00.toc
# 11326 INFO: Target bytecode optimization level: 0
# 11326 INFO: Initializing module dependency graph...
# 11326 INFO: Initializing module graph hook caches...
# ...
